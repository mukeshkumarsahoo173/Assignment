# %% [markdown]
# # Q1. What is Flask Framework? What are the advantages of Flask Framework?
# Ans

# %% [markdown]
# ## Flask
# * Flask is a web framework.
# * Flask allows you to build a web application by providing tools, libraries, and technologies.
# * This web application will be a web page, a wiki, or a big web-based calendar application or commercial website.
# * Flask is classified into a micro-framework that means it has little to no dependencies on external libraries.
#
# ## Advantages of Flask Framework
# There are impressive features to use the flask in your web application framework. Like-
#
# Integrated support for unit testing
#
# Built-in development server and fast debugger
#
# Restful request dispatching
#
# Unicode base
#
# Support for cookies
#
# Templating jinja2
#
# WSGI 1.0 compliant
#
# Plus flask gives you some premier control to develop your project.
#
# HTTP request handling function
#
# Flask has a modular design and lightweight so that it can easy to transit into web framework with some extension
#
# You can plug your favorite ORM
#
# Basic fundamental API is nicely shaped and coherent
#
# Highly flexible
#
# It is easy to deploy the flask in production

# %% [markdown]
# # Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask  #importing Flask
app=Flask(__name__) # creating the sub class app of Flask

@app.route("/") # decoration with app class
def hello_world(): # defining the function
    return "<h1> Hello, World <h1>" # printing the https string code
if __name__ == "__main__": 
    app.run(host="0.0.0.0") #running the code
    
# it gave link http://192.168.29.76:5000/ which has been passed through server and gave the below cell output
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.31:5000
# Press CTRL+C to quit

# %% [markdown]
# ![fl.png](attachment:7cef146f-66fe-4450-b9a5-33bffac5c5ec.png)

# %% [markdown]
# # Q3. What is App routing in Flask? Why do we use app routes?
# Ans

# %% [markdown]
# * App routing is used to map the specific URL with the associated function that is intended to perform some task.
# * The routing technique helps a user remember application URLs and is useful to access the desired page directly without having to navigate from the home page.
# #### The route() decorator in Flask is used to bind URL to a function.

# %% [markdown]
# # Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# # Company Name: ABC Corporation
# # Location: India
# # Contact Detail: 999-999-9999
# Ans

# %%
from flask import Flask

app1= Flask(__name__)

@app1.route("/welcome")

def welcome_page():
    return "<h1> Welcome to ABC Corporation <h1>"


@app1.route("/")
def details():
    return "<h1><pre>Company Name: ABC Corporation <pre> <pre>Location: India <pre> <pre>Contact Detail: 999-999-9999<pre><h2>"
    
    
if __name__ == "__main__":
    app1.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.14:5000
# Press CTRL+C to quit

# %% [markdown]
# ![flask.png](attachment:6278480e-48af-4ce7-86ac-534307ee7cb5.png)

# %% [markdown]
# # Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
# Ans

# %% [markdown]
# * For building URLs in flask, we use the *url_for()* function.
# * The name of the function is accepted as its first argument and any number of keyword arguments.
# * The unknown variable parts in a website are then appended to the URL as query parameters.

# %%
from flask import Flask, redirect, url_for

app2=Flask(__name__)


@app2.route('/pass/<int:score>') 

def pass_x(score):
    return f"<h1> Congratulation! You have Passes with {score} marks <h1>"



@app2.route('/fail/<int:score>')

def fail_x(score):
    return f"<h1> Opps You have Failed with {score} marks better Luck Next Time<h1>"



@app2.route('/result/<int:marks>')

def result_x(marks):
    result=''
    
    
    if marks>=50:
        result="pass_x"  # not the here the variable should match with the previous defination name not only pass or fail
        #in this cell it has been fail_x and pass_x
    else:
        result="fail_x"
        
    #return f"<h1> The Pesron has {result} with {marks} marks <h1>"
    
    return \
redirect(url_for(result, score=marks )) # url takes 2 arguments one the end point and the argument, 
                                                # here score is used in previous methods and marks has been used at the end method

if __name__=="__main__":
    app2.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
