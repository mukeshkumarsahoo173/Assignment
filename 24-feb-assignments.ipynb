# %% [markdown]
# # Q1. List any five functions of the pandas library with execution.
# Ans

# %%
import pandas as pd
df=pd.read_csv("players_data.csv")

# %%
#1
df.shape
# Out:
# (675, 30)

# %%
#2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      675 non-null    object
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     675 non-null    object
#  4   Tm      675 non-null    object
#  5   G       675 non-null    object
#  6   GS      675 non-null    object
#  7   MP      675 non-null    object
#  8   FG      675 non-null    object
#  9   FGA     675 non-null    object
#  10  FG%     673 non-null    object
#  11  3P      675 non-null    object
#  12  3PA     675 non-null    object
#  13  3P%     594 non-null    object
#  14  2P      675 non-null    object
#  15  2PA     675 non-null    object
#  16  2P%     671 non-null    object
#  17  eFG%    673 non-null    object
#  18  FT      675 non-null    object
#  19  FTA     675 non-null    object
#  20  FT%     650 non-null    object
# ...

# %%
#3
df.describe()
# Out:
#          Rk  Player  Pos  Age   Tm    G   GS   MP   FG  FGA  ...   FT%  ORB  \
# count   675     675  675  675  675  675  675  675  675  675  ...   650  675
# unique  493     493   12   21   32   84   81  557  327  458  ...   275  165
# top      Rk  Player   SG   23  TOT   82    0   MP   FG  FGA  ...  .500    1
# freq     24      24  143   86   76   27  179   24   24   24  ...    29   30
#
#         DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# count   675  675  675  675  675  675  675  675
# unique  293  350  249  119   98  177  214  463
# top     DRB  TRB  AST    0    0  TOV   PF  PTS
# freq     24   24   24   29   88   24   24   24
#
# [4 rows x 30 columns]

# %%
#4
df.isna().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        2
# 3P         0
# 3PA        0
# 3P%       81
# 2P         0
# 2PA        0
# 2P%        4
# eFG%       2
# FT         0
# FTA        0
# FT%       25
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
#5
df.drop_duplicates()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %% [markdown]
# # Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.
# Ans

# %%
df1=df.iloc[:,0:3]

# %%
df1.columns=["A","B","C"]

# %%
df1
# Out:
#        A               B   C
# 0      1      Quincy Acy  PF
# 1      2    Jordan Adams  SG
# 2      3    Steven Adams   C
# 3      4     Jeff Adrien  PF
# 4      5   Arron Afflalo  SG
# ..   ...             ...  ..
# 670  490  Thaddeus Young  PF
# 671  490  Thaddeus Young  PF
# 672  490  Thaddeus Young  PF
# 673  491     Cody Zeller   C
# 674  492    Tyler Zeller   C
#
# [675 rows x 3 columns]

# %%
df1.reindex([i for i in range(1,len(df1.A),2)])
# Out:
#        A               B   C
# 1      2    Jordan Adams  SG
# 3      4     Jeff Adrien  PF
# 5      5   Arron Afflalo  SG
# 7      6   Alexis Ajinça   C
# 9      8    Cole Aldrich   C
# ..   ...             ...  ..
# 665  485  Brandan Wright  PF
# 667  487     Tony Wroten  PG
# 669  489      Nick Young  SG
# 671  490  Thaddeus Young  PF
# 673  491     Cody Zeller   C
#
# [337 rows x 3 columns]

# %% [markdown]
# # Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console. For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.
# Ans

# %%
df=pd.DataFrame({"Product":["a", 'b', 'c', 'd', 'e'], "Value":[10,20,30,40,50]})
df
# Out:
#   Product  Value
# 0       a     10
# 1       b     20
# 2       c     30
# 3       d     40
# 4       e     50

# %%
def first_3(Value): 
    return df['Value'][:3].sum()
first_3("Value")
# Out:
# 60

# %% [markdown]
# # Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.
# Ans

# %%
df=pd.DataFrame({"Text":["hello how are you", "this is a pandas", "this is python and we are learning python and pandas", 
                       "how the world is beautifull"]})
df
# Out:
#                                                 Text
# 0                                  hello how are you
# 1                                   this is a pandas
# 2  this is python and we are learning python and ...
# 3                        how the world is beautifull

# %%
df["Word-Count"]=df.Text.apply(lambda x:len(x.split()))

# %%
df
# Out:
#                                                 Text  Word-Count
# 0                                  hello how are you           4
# 1                                   this is a pandas           4
# 2  this is python and we are learning python and ...          10
# 3                        how the world is beautifull           5

# %% [markdown]
# # Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# ## size
# * Syntax: dataframe.size
# * Return : Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
# ## shape
# * Syntax: dataframe.shape
# * Return : Returns tuple of shape (Rows, columns) of dataframe/series

# %%
print(f"shape is {df1.shape}")
print(f"Size is {df1.size}")
# Out:
# shape is (675, 3)
# Size is 2025

# %% [markdown]
# # Q6. Which function of pandas do we use to read an excel file?

# %%
# exmp

pd.read_excel("LUSID.xlsx")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %% [markdown]
# # Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address. The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
df=pd.DataFrame({"Email":["ram.mukesh@gmail.com", "sahoobijaya@gmail.com", "jayshreeram@gmail.com", "krishna@gmail.com"]})
df
# Out:
#                    Email
# 0   ram.mukesh@gmail.com
# 1  sahoobijaya@gmail.com
# 2  jayshreeram@gmail.com
# 3      krishna@gmail.com

# %%
df["username"]=df.Email.apply(lambda x:x.split("@")[0])

# %%
df
# Out:
#                    Email     username
# 0   ram.mukesh@gmail.com   ram.mukesh
# 1  sahoobijaya@gmail.com  sahoobijaya
# 2  jayshreeram@gmail.com  jayshreeram
# 3      krishna@gmail.com      krishna

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows. For example, if df contains the following values:
#
# ![download.png](attachment:3f92cb33-3e67-42f4-b319-4fe814e0e8ce.png)
#
# Your function should select the following rows:
#
# A B C
#
# 1 8 2 7
#
# 4 9 1 2
#
# The function should return a new DataFrame that contains only the selected rows.

# %%
df=pd.DataFrame({"A":[3,8,6,2,9],
                "B": [5,2,9,3,1],
                "C":[1,7,4,5,2]}
                   )
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def filter():
    df1=df[(df.A>5) & (df.B<10)]
    return df1

# %%
filter()
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# # Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
df=pd.DataFrame({"P":["a","b","c","d","e","f","g","h"],
    "Value":[112,223,453,324,89,101,65,3000 ]})
df
# Out:
#    P  Value
# 0  a    112
# 1  b    223
# 2  c    453
# 3  d    324
# 4  e     89
# 5  f    101
# 6  g     65
# 7  h   3000

# %%
def description_x(col):
    
    print(f"Mean = {df[col].mean()}")
    print(f"Median = {df[col].median()}")
    print(f"Standard deviation = {df[col].std()}")
description_x("Value")
# Out:
# Mean = 545.875
# Median = 167.5
# Standard deviation = 1000.7831843825401

# %% [markdown]
# # Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
import warnings
warnings.filterwarnings('ignore')
df = pd.DataFrame({'Date':['10/2/2023', '11/2/2023', '12/2/2023', '13/2/2023',\
                           "14/02/2023",'10/2/2023', '11/2/2023', '12/12/2022', '03/1/2023',"14/12/2022"],\
                   
                    'Sales':[10000, 5000, 15000, 2000,2000,3000,1000,2435,6000,1200]})
 
# Print the dataframe
print(df)
print("#############################################################")
#get the moving average
df.Date=pd.to_datetime(df.Date)
df.set_index(df.Date, inplace=True) # setting date col as index

print()

print("Moving Average")


round(df.Sales.rolling(window=7).mean().fillna(0),2)
# Out:
#          Date  Sales
# 0   10/2/2023  10000
# 1   11/2/2023   5000
# 2   12/2/2023  15000
# 3   13/2/2023   2000
# 4  14/02/2023   2000
# 5   10/2/2023   3000
# 6   11/2/2023   1000
# 7  12/12/2022   2435
# 8   03/1/2023   6000
# 9  14/12/2022   1200
# #############################################################
#
# Moving Average
# Date
# 2023-10-02       0.0
# 2023-11-02       0.0
# 2023-12-02       0.0
# 2023-02-13       0.0
# 2023-02-14       0.0
# 2023-10-02       0.0
# 2023-11-02    5428.6
# 2022-12-12    4347.9
# 2023-03-01    4490.7
# 2022-12-14    2519.3
# Name: Sales, dtype: float64
